# %% [markdown]
# # DATA COLLECTION
#
# Data collected from https://en.wikipedia.org/wiki/List_of_Netflix_original_programming

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the Wikipedia page
url = 'https://en.wikipedia.org/wiki/List_of_Netflix_original_programming#Episodic'

# Send a request to the webpage
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all tables on the page
tables = soup.find_all('table', {'class': 'wikitable'})

# Print out the headers of all tables to find the correct one
for i, table in enumerate(tables):
    headers = table.find_all('th')
    header_texts = [header.get_text(strip=True) for header in headers]
    print(f"Table {i} headers: {header_texts}")
# Out:
# Table 0 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status', 'Awaiting release']
# Table 1 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status', 'Awaiting release']
# Table 2 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status']
# Table 3 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Status', 'Awaiting release']
# Table 4 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Status', 'Awaiting release']
# Table 5 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Status', 'Awaiting release']
# Table 6 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status']
# Table 7 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status']
# Table 8 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status', 'Awaiting release']
# Table 9 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status']
# Table 10 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status']
# Table 11 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status', 'Awaiting release']
# Table 12 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status', 'Awaiting release']
# Table 13 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status']
# Table 14 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status', 'Awaiting release']
# Table 15 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status']
# Table 16 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status', 'Awaiting release']
# Table 17 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status', 'Awaiting release']
# Table 18 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status', 'Awaiting release']
# Table 19 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status']
# Table 20 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status']
# Table 21 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Status', 'Awaiting release']
# Table 22 headers: ['Title', 'Subject', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Status', 'Awaiting release']
# Table 23 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Status', 'Awaiting release']
# Table 24 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Status', 'Awaiting release']
# Table 25 headers: ['Title', 'Genre', 'Previous network(s)', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Status']
# Table 26 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Status']
# Table 27 headers: ['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Netflix exclusive region', 'Status']
# Table 28 headers: ['Title', 'Genre', 'Partner/Country', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Netflix exclusive regions', 'Status']
# Table 29 headers: ['Title', 'Genre', 'Previous network(s)', 'Premiere', 'Seasons', 'Runtime', 'Language', 'Netflix exclusive region', 'Status']
# Table 30 headers: ['Title', 'Genre', 'Premiere']
# Table 31 headers: ['Title', 'Genre', 'Premiere']
# Table 32 headers: ['Title', 'Genre', 'Premiere']
# Table 33 headers: ['Title', 'Genre', 'Premiere']
# Table 34 headers: ['Title', 'Genre', 'Language', 'Premiere']
# Table 35 headers: ['Title', 'Genre', 'Premiere']
# Table 36 headers: ['Title', 'Genre', 'Premiere']
# Table 37 headers: ['Title', 'Genre', 'Premiere']
# Table 38 headers: ['Title', 'Genre', 'Premiere']
# Table 39 headers: ['Title', 'Genre', 'Premiere']
# Table 40 headers: ['Title', 'Genre', 'Premiere']
# Table 41 headers: ['Title', 'Genre', 'Premiere']
# Table 42 headers: ['Title', 'Genre', 'Premiere']
# Table 43 headers: ['Title', 'Genre', 'Premiere']
# Table 44 headers: ['Title', 'Genre', 'Premiere']
# Table 45 headers: ['Title', 'Genre', 'Premiere']
# Table 46 headers: ['Title', 'Genre', 'Premiere']
# Table 47 headers: ['Title', 'Genre', 'Language', 'Premiere']
# Table 48 headers: ['Title', 'Subject', 'Language', 'Premiere']
# Table 49 headers: ['Title', 'Genre', 'Language', 'Premiere']
# Table 50 headers: ['Title', 'Partner/Country', 'Genre', 'Language', 'Premiere']
# Table 51 headers: ['Title', 'Genre', 'Prev.network(s)', 'Premiere', 'Seasons', 'Runtime', 'Language']
# Table 52 headers: ['Title', 'Genre', 'Language', 'Premiere']
# Table 53 headers: ['Title', 'Genre']

# %%
# Based on the output, find the index of the "Drama" table
# let's take the "Drama" table at index 0
drama_table_index = 0
drama_table = tables[drama_table_index]

# Extract table data
data = []
for row in drama_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
drama_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
# 9        1 season, 8 episodes  26–30 min
# 10       1 season, 6 episodes  31–37 min
# 11       1 season, 5 episodes  19–26 min
# 12       1 season, 8 episodes  41–67 min
# 13       1 season, 7 episodes  44–56 min
# 14       1 season, 6 episodes  18–22 min
# 15       1 season, 4 episodes  43–50 min
# 16       1 season, 8 episodes  45–56 min
# 17                       None       None
# 18  1 season, 10 episodes[49]     30 min
#
#                                                Status Language
# 0   Season 4 part 2 due to premiere on September 1...  English
# 1               Renewed for parts 6–7 (final)[36][37]  English
# 2         Final season due to premiere in 2024[6][38]  English
# 3                                         Renewed[39]  English
# 4                                             Pending  English
# 5                                             Pending  English
# 6                                         Renewed[40]  English
# 7                                         Renewed[41]  English
# 8                                         Renewed[42]  English
# 9                                             Pending  English
# 10                                            Pending  English
# 11                                        Renewed[43]  English
# 12                                        Renewed[44]  English
# 13                                            Pending  English
# 14                                        Renewed[45]  English
# 15                                            Pending  English
# 16                                            Pending  English
# 17                                               None  English
# 18                                            Pending  English

# %%
# Now with Kids family
kids_family_table_index = 2
kids_family_table = tables[kids_family_table_index]

# Extract table data
data = []
for row in kids_family_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
kids_family_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
kids_family_df['Language'] = 'English'
kids_family_df
# Out:
#                         Title             Genre           Premiere  \
# 0                Heartstopper        Teen drama     April 22, 2022
# 1                   One Piece  Action-adventure    August 31, 2023
# 2  Avatar: The Last Airbender           Fantasy  February 22, 2024
# 3                   Geek Girl        Teen drama       May 30, 2024
#
#                   Seasons    Runtime  \
# 0  2 seasons, 16 episodes  26–40 min
# 1    1 season, 8 episodes  49–64 min
# 2    1 season, 8 episodes  47–63 min
# 3   1 season, 10 episodes  28–37 min
#
#                                               Status Language
# 0  Season 3 due to premiere on October 3, 2024[50...  English
# 1               Season 2 due to premiere in 2025[52]  English
# 2                Renewed for seasons 2–3 (final)[53]  English
# 3                                            Pending  English

# %%
animation_table_index = 3
animation_table = tables[animation_table_index]

# Extract table data
data = []
for row in animation_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
animation_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime','Language', 'Status'])
animation_df
kids_family_df
# Out:
#                         Title             Genre           Premiere  \
# 0                Heartstopper        Teen drama     April 22, 2022
# 1                   One Piece  Action-adventure    August 31, 2023
# 2  Avatar: The Last Airbender           Fantasy  February 22, 2024
# 3                   Geek Girl        Teen drama       May 30, 2024
#
#                   Seasons    Runtime  \
# 0  2 seasons, 16 episodes  26–40 min
# 1    1 season, 8 episodes  49–64 min
# 2    1 season, 8 episodes  47–63 min
# 3   1 season, 10 episodes  28–37 min
#
#                                               Status Language
# 0  Season 3 due to premiere on October 3, 2024[50...  English
# 1               Season 2 due to premiere in 2025[52]  English
# 2                Renewed for seasons 2–3 (final)[53]  English
# 3                                            Pending  English

# %%
# Based on the output, find the index of the anime table

anime_table_index = 4
anime_table = tables[anime_table_index]

# Extract table data
data = []
for row in anime_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
anime_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime','Language', 'Status'])
anime_df
# Out:
#                                         Title  \
# 0                               Blood of Zeus
# 1                       Castlevania: Nocturne
# 2                            Good Night World
# 3     Captain Laserhawk: A Blood Dragon Remix
# 4                                       Pluto
# 5                                    Onimusha
# 6                                   Akuma-kun
# 7                     Scott Pilgrim Takes Off
# 8                                   My Daemon
# 9                                     Onmyōji
# 10                          Pokémon Concierge
# 11                       The Grimm Variations
# 12                                    T・P BON
# 13         Garouden: The Way of the Lone Wolf
# 14                              Rising Impact
# 15                            Terminator Zero
# 16                                       None
# 17  Tomb Raider: The Legend of Lara Croft[64]
# 18          Gundam: Requiem for Vengeance[66]
#
#                                Genre              Premiere  \
# 0                     Fantasy action      October 27, 2020
# 1                       Dark fantasy    September 28, 2023
# 2                            Fantasy      October 12, 2023
# 3                    Science fiction      October 19, 2023
# 4                    Science fiction      October 26, 2023
# 5                   Action-adventure      November 2, 2023
# 6                            Fantasy      November 9, 2023
# 7            Fantasy romantic comedy     November 17, 2023
# 8                  Fantasy adventure     November 23, 2023
# 9                 Historical fantasy     November 28, 2023
# 10               Stop-motion fantasy     December 28, 2023
# 11            Dark fantasy anthology        April 17, 2024
# 12                   Science fiction           May 2, 2024
# 13                      Martial arts          May 23, 2024
# 14                            Sports         June 22, 2024
# 15                   Science fiction       August 29, 2024
# 16                              None                  None
# 17                  Action-adventure  October 10, 2024[65]
# 18  Mecha / military science fiction  October 17, 2024[67]
#
#                    Seasons    Runtime  Language  \
# 0   2 seasons, 16 episodes  24–37 min   English
# 1     1 season, 8 episodes  24–30 min   English
# 2    1 season, 12 episodes  24–30 min  Japanese
# 3     1 season, 6 episodes  20–25 min   English
# 4     1 season, 8 episodes  56–71 min  Japanese
# 5     1 season, 8 episodes  22–36 min  Japanese
# 6    1 season, 12 episodes  21–28 min  Japanese
# 7     1 season, 8 episodes  26–29 min   English
# 8    1 season, 13 episodes  23–31 min  Japanese
# 9    1 season, 13 episodes  25–27 min  Japanese
# 10    1 season, 4 episodes  14–20 min  Japanese
# 11    1 season, 6 episodes  32–46 min  Japanese
# 12  2 seasons, 24 episodes  26–33 min  Japanese
# 13    1 season, 8 episodes  23–28 min  Japanese
# 14  2 seasons, 26 episodes  22–28 min  Japanese
# 15    1 season, 8 episodes  25–29 min  Japanese
# 16                    None       None      None
# 17   1 season, 10 episodes        TBA   English
# 18    1 season, 6 episodes        TBA   English
#
#                                       Status
# 0   Final season due to premiere in 2025[61]
# 1                                Renewed[62]
# 2                                    Pending
# 3                                    Pending
# 4                                    Pending
# 5                                    Pending
# 6                                    Pending
# 7                                    Pending
# 8                                    Pending
# 9                                    Pending
# 10                               Renewed[63]
# 11                                   Pending
# 12                                   Pending
# 13                                   Pending
# 14                                   Pending
# 15                                   Pending
# 16                                      None
# 17                                   Pending
# 18                                   Pending

# %%
# Based on the output, find the index of the "Kids & Family" table
kids_family_table_index = 5
kids_family_table = tables[kids_family_table_index]

# Extract table data
data = []
for row in kids_family_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
fam_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime','Language', 'Status'])
fam_df
# Out:
#                                           Title  \
# 0                             The Dragon Prince
# 1                             Gabby's Dollhouse
# 2                                  Go, Dog. Go!
# 3                                     Oggy Oggy
# 4                            The Creature Cases
# 5                                   Sonic Prime
# 6                                Princess Power
# 7                             Not Quite Narwhal
# 8                                   Supa Team 4
# 9                              Dew Drop Diaries
# 10                  Little Baby Bum: Music Time
# 11                              Unicorn Academy
# 12                               CoComelon Lane
# 13                      Mighty Bheem's Playtime
# 14                          Dee & Friends in Oz
# 15                        Hot Wheels Let's Race
# 16                                Bad Dinosaurs
# 17                 Jurassic World: Chaos Theory
# 18                                    Wonderoos
# 19                                         None
# 20                   Mighty MonsterWheelies[70]
# 21  Barbie Mysteries: The Great Horse Chase[74]
#
#                                Genre              Premiere  \
# 0           Fantasy action adventure    September 14, 2018
# 1        Preschool adventure fantasy       January 5, 2021
# 2                   Preschool comedy      January 26, 2021
# 3         Preschool adventure comedy       August 24, 2021
# 4            Preschool action comedy        April 12, 2022
# 5           Fantasy action adventure     December 15, 2022
# 6                    Fantasy musical      January 30, 2023
# 7                  Preschool fantasy         June 19, 2023
# 8            Superhero action comedy         July 20, 2023
# 9                  Preschool fantasy         July 24, 2023
# 10                 Preschool musical    September 25, 2023
# 11          Fantasy action adventure      November 2, 2023
# 12                 Preschool musical     November 17, 2023
# 13                  Preschool comedy      January 29, 2024
# 14         Fantasy adventure musical      February 5, 2024
# 15                  Adventure comedy         March 4, 2024
# 16                  Adventure comedy        March 28, 2024
# 17  Science fiction action adventure          May 24, 2024
# 18                  Preschool comedy         July 15, 2024
# 19                              None                  None
# 20                         Preschool  October 14, 2024[69]
# 21                  Adventure comedy  November 1, 2024[69]
#
#                     Seasons    Runtime            Language  \
# 0    6 seasons, 54 episodes  24–33 min             English
# 1   10 seasons, 70 episodes  23–30 min             English
# 2    4 seasons, 40 episodes     24 min             English
# 3    3 seasons, 52 episodes     22 min  No spoken language
# 4   3 chapters, 20 episodes  27–29 min             English
# 5    3 seasons, 23 episodes  21–43 min             English
# 6    3 seasons, 45 episodes  14–34 min             English
# 7    2 seasons, 39 episodes  13–24 min             English
# 8    2 seasons, 16 episodes  26–30 min             English
# 9    2 seasons, 40 episodes  13–30 min             English
# 10   2 seasons, 18 episodes  23–42 min             English
# 11  2 chapters, 19 episodes  24–75 min             English
# 12   3 seasons, 15 episodes  25–33 min             English
# 13    1 season, 10 episodes  14–15 min  No spoken language
# 14     2 parts, 17 episodes  25–47 min             English
# 15    1 season, 10 episodes  23–24 min             English
# 16     1 season, 8 episodes  20–22 min             English
# 17    1 season, 10 episodes     23 min             English
# 18    1 season, 20 episodes     14 min             English
# 19                     None       None                None
# 20                      TBA        TBA             English
# 21               8 episodes     25 min             English
#
#                                                Status
# 0   Final season due to premiere on December 19, 2...
# 1                                         Renewed[70]
# 2                                             Pending
# 3                                             Pending
# 4   Chapter 4 due to premiere on December 2, 2024[...
# 5                                             Pending
# 6                                             Pending
# 7                                             Pending
# 8                                             Pending
# 9                                             Pending
# 10                                            Pending
# 11                                            Pending
# 12                                            Pending
# 13                                            Pending
# 14                                            Pending
# 15  Season 2 due to premiere on September 9, 2024[...
# 16                                            Pending
# 17  Season 2 due to premiere October 17, 2024[72][73]
# 18  Season 2 due to premiere on November 18, 2024[69]
# 19                                               None
# 20                                            Pending
# 21                                            Pending

# %%
arabic_table_index = 6
arabic_table = tables[arabic_table_index]

# Extract table data
data = []
for row in arabic_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
arabic_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
arabic_df['Language'] = 'Arabic'
arabic_df
# Out:
#                        Title         Genre           Premiere  \
# 0  AlRawabi School for Girls         Drama    August 12, 2021
# 1                Finding Ola  Comedy drama   February 3, 2022
# 2               The Exchange         Drama   February 8, 2023
# 3               Crashing Eid  Comedy drama  November 15, 2023
#
#                   Seasons    Runtime  \
# 0  2 seasons, 12 episodes  44–71 min
# 1    1 season, 6 episodes  46–55 min
# 2    1 season, 6 episodes  48–57 min
# 3    1 season, 4 episodes  46–48 min
#
#                                      Status Language
# 0                                   Pending   Arabic
# 1  Season 2 due to premiere in 2024[75][76]   Arabic
# 2      Season 2 due to premiere in 2024[75]   Arabic
# 3                                   Pending   Arabic

# %%
french_table_index = 7
french_table = tables[french_table_index]

# Extract table data
data = []
for row in french_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame and add French in language column
french_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
french_df['Language'] = 'French'
french_df
# Out:
#          Title             Genre          Premiere                 Seasons  \
# 0        Lupin  Mystery thriller   January 8, 2021    3 parts, 17 episodes
# 1    Represent            Comedy  January 20, 2023  2 seasons, 12 episodes
# 2  Blood Coast       Crime drama  December 6, 2023    1 season, 6 episodes
# 3       Furies            Action     March 1, 2024    1 season, 8 episodes
#
#      Runtime                                Status Language
# 0  40–52 min                               Pending   French
# 1  26–34 min                               Pending   French
# 2  48–56 min  Season 2 due to premiere in 2025[77]   French
# 3  39–50 min                               Pending   French

# %%
german_table_index = 8
german_table = tables[german_table_index]

# Extract table data
data = []
for row in german_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
german_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
german_df['Language'] = 'German'
german_df
# Out:
#                              Title             Genre              Premiere  \
# 0  How to Sell Drugs Online (Fast)       Dark comedy          May 31, 2019
# 1                             Kleo          Thriller       August 19, 2022
# 2                      The Empress  Historical drama    September 29, 2022
# 3                           Crooks       Crime drama         April 4, 2024
# 4                             None              None                  None
# 5         Murder Mindfully[84][79]       Dark comedy  October 31, 2024[85]
#
#                   Seasons    Runtime  \
# 0  3 seasons, 18 episodes  24–36 min
# 1  2 seasons, 14 episodes  41–56 min
# 2    1 season, 6 episodes  51–61 min
# 3    1 season, 8 episodes  39–66 min
# 4                    None       None
# 5              8 episodes        TBA
#
#                                          Status Language
# 0  Season 4 due to premiere in 2024[78][79][80]   German
# 1                                       Pending   German
# 2      Season 2 due to premiere in 2024[81][82]   German
# 3                                   Renewed[83]   German
# 4                                          None   German
# 5                                    Miniseries   German

# %%
hindi_table_index = 9
hindi_table = tables[hindi_table_index]

# Extract table data
data = []
for row in hindi_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
hindi_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
hindi_df['Language'] = 'Hindi'
hindi_df
# Out:
#                              Title                       Genre  \
# 0                      Delhi Crime           Police procedural
# 1                              She                 Crime drama
# 2                       Mismatched             Romantic comedy
# 3          Yeh Kaali Kaali Ankhein           Romantic thriller
# 4                            Class         Teen crime thriller
# 5                       Rana Naidu                 Crime drama
# 6                   Guns & Gulaabs       Crime comedy thriller
# 7                      Kaala Paani                       Drama
# 8                      Killer Soup  Dark comedy/Crime thriller
# 9                 Maamla Legal Hai          Legal comedy drama
# 10  Heeramandi: The Diamond Bazaar              Romantic drama
# 11      Tribhuvan Mishra CA Topper                 Dark comedy
#
#              Premiere                 Seasons    Runtime  \
# 0      March 22, 2019  2 seasons, 12 episodes  36–64 min
# 1      March 20, 2020  2 seasons, 14 episodes  31–51 min
# 2   November 20, 2020  2 seasons, 14 episodes  29–42 min
# 3    January 14, 2022    1 season, 8 episodes  31–51 min
# 4    February 3, 2023    1 season, 8 episodes  47–58 min
# 5      March 10, 2023   1 season, 10 episodes  39–50 min
# 6     August 18, 2023    1 season, 7 episodes  44–81 min
# 7    October 18, 2023    1 season, 7 episodes  57–70 min
# 8    January 11, 2024    1 season, 8 episodes  43–59 min
# 9       March 1, 2024    1 season, 8 episodes  27–38 min
# 10        May 1, 2024    1 season, 8 episodes  46–67 min
# 11      July 18, 2024    1 season, 9 episodes  44–67 min
#
#                                       Status Language
# 0                                Renewed[86]    Hindi
# 1   Season 3 due to premiere in 2024[87][86]    Hindi
# 2                                Renewed[86]    Hindi
# 3                                Renewed[88]    Hindi
# 4                                Renewed[89]    Hindi
# 5                                Renewed[90]    Hindi
# 6                                Renewed[91]    Hindi
# 7                                Renewed[92]    Hindi
# 8                                    Pending    Hindi
# 9                                Renewed[93]    Hindi
# 10                               Renewed[94]    Hindi
# 11                                   Pending    Hindi

# %%
indonesian_table_index = 10
indonesian_table = tables[indonesian_table_index]

# Extract table data
data = []
for row in indonesian_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
indonesian_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
indonesian_df['Language'] = 'Indonesian'
indonesian_df
# Out:
#                                    Title                      Genre  \
# 0                         Cigarette Girl               Period drama
# 1                           Comedy Chaos                     Sitcom
# 2  Joko Anwar's Nightmares and Daydreams  Science fiction anthology
#
#             Premiere                Seasons    Runtime   Status    Language
# 0   November 2, 2023   1 season, 5 episodes  58–74 min  Pending  Indonesian
# 1  February 16, 2024  1 season, 10 episodes  27–34 min  Pending  Indonesian
# 2      June 14, 2024   1 season, 7 episodes  46–62 min  Pending  Indonesian

# %%
italian_table_index = 11
italian_table = tables[italian_table_index]

# Extract table data
data = []
for row in italian_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
italian_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
italian_df['Language'] = 'Italian'
italian_df
# Out:
#                              Title               Genre  \
# 0                          Di4ries       Coming-of-age
# 1   Everything Calls for Salvation               Drama
# 2                 I Hate Christmas              Comedy
# 3  The Law According to Lidia Poët  Period legal drama
# 4                     Suburræterna         Crime drama
# 5                         Supersex              Biopic
# 6     Brigands: The Quest for Gold    Historical drama
# 7                             None                None
# 8          Deceitful Love[99][100]      Romantic drama
#
#                     Premiere                 Seasons    Runtime  \
# 0               May 18, 2022  2 seasons, 29 episodes  24–52 min
# 1           October 14, 2022    1 season, 7 episodes  42–49 min
# 2           December 7, 2022  2 seasons, 12 episodes  28–39 min
# 3          February 15, 2023    1 season, 6 episodes  44–52 min
# 4          November 14, 2023    1 season, 8 episodes  40–49 min
# 5              March 6, 2024    1 season, 7 episodes  42–55 min
# 6             April 23, 2024    1 season, 6 episodes  39–58 min
# 7                       None                    None       None
# 8  October 9, 2024[101][102]                     TBA        TBA
#
#                                               Status Language
# 0                                            Pending  Italian
# 1  Season 2 due to premiere on September 26, 2024...  Italian
# 2                                            Pending  Italian
# 3       Season 2 due to premiere in 2024[96][97][98]  Italian
# 4                                            Pending  Italian
# 5                                            Pending  Italian
# 6                                            Pending  Italian
# 7                                               None  Italian
# 8                                         Miniseries  Italian

# %%
japanese_table_index = 12
japanese_table = tables[japanese_table_index]

# Extract table data
data = []
for row in japanese_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
japanese_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
japanese_df['Language'] = 'Japanese'
japanese_df
# Out:
#                         Title                    Genre  \
# 0         Alice in Borderland         Fantasy thriller
# 1                YuYu Hakusho  Fantasy action-adveture
# 2             House of Ninjas          Action thriller
# 3             Tokyo Swindlers           Crime thriller
# 4               Chastity High               Teen drama
# 5                        None                     None
# 6  The Queen of Villains[104]             Sports drama
# 7         Beyond Goodbye[106]           Romantic drama
#
#                       Premiere                 Seasons    Runtime  \
# 0            December 10, 2020  2 seasons, 16 episodes  41–80 min
# 1            December 14, 2023    1 season, 5 episodes  44–55 min
# 2            February 15, 2024    1 season, 8 episodes  51–55 min
# 3                July 25, 2024    1 season, 7 episodes  37–66 min
# 4              August 29, 2024    1 season, 8 episodes  44–54 min
# 5                         None                    None       None
# 6      September 19, 2024[105]                     TBA        TBA
# 7  November 14, 2024[107][108]                     TBA        TBA
#
#          Status  Language
# 0  Renewed[103]  Japanese
# 1       Pending  Japanese
# 2       Pending  Japanese
# 3       Pending  Japanese
# 4       Pending  Japanese
# 5          None  Japanese
# 6       Pending  Japanese
# 7       Pending  Japanese

# %%
korean_table_index = 13
korean_table = tables[korean_table_index]

# Extract table data
data = []
for row in korean_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
korean_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
korean_df['Language'] = 'Korean'
korean_df
# Out:
#                     Title                         Genre            Premiere  \
# 0              Squid Game             Survival thriller  September 17, 2021
# 1               Hellbound            Supernatural drama   November 19, 2021
# 2      All of Us Are Dead             Zombie apocalypse    January 28, 2022
# 3             Bloodhounds                  Action drama        June 9, 2023
# 4     Song of the Bandits           Period action drama  September 22, 2023
# 5                  Doona!  Coming-of-age romantic drama    October 20, 2023
# 6  Daily Dose of Sunshine          Medical comedy drama    November 3, 2023
# 7    Gyeongseong Creature           Historical thriller   December 22, 2023
# 8        A Killer Paradox    Crime thriller dark comedy    February 9, 2024
#
#                  Seasons    Runtime  \
# 0   1 season, 9 episodes  32–63 min
# 1   1 season, 6 episodes  42–60 min
# 2  1 season, 12 episodes  53–71 min
# 3   1 season, 8 episodes  54–74 min
# 4   1 season, 9 episodes  48–69 min
# 5   1 season, 9 episodes  42–49 min
# 6  1 season, 12 episodes  52–72 min
# 7  1 season, 10 episodes  64–78 min
# 8   1 season, 8 episodes  45–63 min
#
#                                               Status Language
# 0  Season 2 due to premiere on December 26, 2024[...   Korean
# 1         Season 2 due to premiere in 2024[110][111]   Korean
# 2                                       Renewed[112]   Korean
# 3                                       Renewed[113]   Korean
# 4                                            Pending   Korean
# 5                                            Pending   Korean
# 6                                            Pending   Korean
# 7  Season 2 due to premiere on September 27, 2024...   Korean
# 8                                            Pending   Korean

# %%
mandarin_table_index = 14
mandarin_table = tables[mandarin_table_index]

# Extract table data
data = []
for row in mandarin_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
mandarin_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
mandarin_df['Language'] = 'Mandarin'
mandarin_df
# Out:
#                          Title                     Genre  \
# 0            The Victims' Game                  Thriller
# 1                At the Moment  Romantic drama/anthology
# 2         Let's Talk About CHU           Romantic comedy
# 3                  GG Precinct              Crime comedy
# 4                         None                      None
# 5  Born for the Spotlight[116]                     Drama
#
#                 Premiere                 Seasons    Runtime   Status  Language
# 0         April 30, 2020  2 seasons, 16 episodes  51–67 min  Pending  Mandarin
# 1      November 10, 2023   1 season, 10 episodes  46–58 min  Pending  Mandarin
# 2       February 2, 2024    1 season, 8 episodes  43–58 min  Pending  Mandarin
# 3        August 22, 2024    1 season, 6 episodes  38–50 min  Pending  Mandarin
# 4                   None                    None       None     None  Mandarin
# 5  November 7, 2024[117]   1 season, 12 episodes        TBA  Pending  Mandarin

# %%
polish_table_index = 15
polish_table = tables[polish_table_index]

# Extract table data
data = []
for row in polish_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
polish_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
polish_df['Language'] = 'Polish'
polish_df
# Out:
#                   Title           Genre           Premiere  \
# 0  The Green Glove Gang     Dark comedy   October 19, 2022
# 1    Absolute Beginners  Romantic drama   October 25, 2023
# 2              Feedback           Drama  November 15, 2023
# 3                  1670          Comedy  December 13, 2023
# 4       Detective Forst     Crime drama   January 11, 2024
#
#                   Seasons    Runtime        Status Language
# 0  2 seasons, 16 episodes  28–38 min       Pending   Polish
# 1    1 season, 6 episodes  45–47 min       Pending   Polish
# 2    1 season, 5 episodes  43–55 min       Pending   Polish
# 3    1 season, 8 episodes  29–37 min  Renewed[118]   Polish
# 4    1 season, 6 episodes  41–45 min       Pending   Polish

# %%
portuguese_table_index = 16
portuguese_table = tables[polish_table_index]

# Extract table data
data = []
for row in portuguese_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
portuguese_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
portuguese_df['Language'] = 'Portuguese'
portuguese_df
# Out:
#                   Title           Genre           Premiere  \
# 0  The Green Glove Gang     Dark comedy   October 19, 2022
# 1    Absolute Beginners  Romantic drama   October 25, 2023
# 2              Feedback           Drama  November 15, 2023
# 3                  1670          Comedy  December 13, 2023
# 4       Detective Forst     Crime drama   January 11, 2024
#
#                   Seasons    Runtime        Status    Language
# 0  2 seasons, 16 episodes  28–38 min       Pending  Portuguese
# 1    1 season, 6 episodes  45–47 min       Pending  Portuguese
# 2    1 season, 5 episodes  43–55 min       Pending  Portuguese
# 3    1 season, 8 episodes  29–37 min  Renewed[118]  Portuguese
# 4    1 season, 6 episodes  41–45 min       Pending  Portuguese

# %%
spanish_table_index = 17
spanish_table = tables[spanish_table_index]

# Extract table data
data = []
for row in spanish_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
spanish_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
spanish_df['Language'] = 'Spanish'
spanish_df
# Out:
#                                     Title              Genre  \
# 0                                 Valeria       Comedy drama
# 1                             Alpha Males             Comedy
# 2                           The Snow Girl           Thriller
# 3                             Eva Lasting     Romantic drama
# 4                         Community Squad             Comedy
# 5                         Pact of Silence         Telenovela
# 6                     Nothing to See Here       Comedy drama
# 7                          The Influencer              Drama
# 8   Cindy la Regia: The High School Years      Coming-of-age
# 9                               The Manny             Comedy
# 10                                 Berlin  Heist crime drama
# 11                           Baby Bandito        Heist drama
# 12                               Bandidos        Heist drama
# 13                             Iron Reign           Thriller
# 14            The Hijacking of Flight 601              Drama
# 15                         Raising Voices         Teen drama
# 16                       Gangs of Galicia        Crime drama
# 17                           The Accident              Drama
# 18                             Breathless      Medical drama
# 19                                   None               None
# 20                      Envious[133][134]             Comedy
# 21                     We Were Kings[136]              Drama
#
#                    Premiere                 Seasons    Runtime  \
# 0               May 8, 2020  3 seasons, 24 episodes  37–46 min
# 1         December 30, 2022  2 seasons, 20 episodes  30–40 min
# 2          January 27, 2023    1 season, 6 episodes  42–49 min
# 3         February 15, 2023  2 seasons, 23 episodes  36–50 min
# 4         February 17, 2023    1 season, 8 episodes  23–29 min
# 5          October 11, 2023   1 season, 18 episodes  35–43 min
# 6         November 17, 2023    1 season, 8 episodes  22–27 min
# 7         December 13, 2023   1 season, 60 episodes  45–61 min
# 8         December 20, 2023    1 season, 7 episodes  24–32 min
# 9         December 24, 2023   1 season, 10 episodes  30–41 min
# 10        December 29, 2023    1 season, 8 episodes  42–60 min
# 11         January 31, 2024    1 season, 8 episodes  34–43 min
# 12           March 13, 2024    1 season, 7 episodes  41–50 min
# 13           March 15, 2024    1 season, 8 episodes  47–72 min
# 14           April 10, 2024    1 season, 6 episodes  44–59 min
# 15             May 31, 2024    1 season, 8 episodes  41–48 min
# 16            June 21, 2024    1 season, 7 episodes  41–56 min
# 17          August 21, 2024   1 season, 10 episodes  40–50 min
# 18          August 30, 2024    1 season, 8 episodes  40–51 min
# 19                     None                    None       None
# 20  September 18, 2024[135]                     TBA        TBA
# 21       September 25, 2024                     TBA        TBA
#
#                                Status Language
# 0       Renewed for final season[124]  Spanish
# 1   Renewed for seasons 3–4[125][126]  Spanish
# 2                        Renewed[127]  Spanish
# 3                        Renewed[128]  Spanish
# 4                        Renewed[129]  Spanish
# 5                             Pending  Spanish
# 6                        Renewed[130]  Spanish
# 7                             Pending  Spanish
# 8                             Pending  Spanish
# 9                        Renewed[131]  Spanish
# 10                       Renewed[132]  Spanish
# 11                            Pending  Spanish
# 12                            Pending  Spanish
# 13                            Pending  Spanish
# 14                            Pending  Spanish
# 15                            Pending  Spanish
# 16                            Pending  Spanish
# 17                            Pending  Spanish
# 18                            Pending  Spanish
# 19                               None  Spanish
# 20                            Pending  Spanish
# 21                            Pending  Spanish

# %%
swedish_table_index = 18
swedish_table = tables[swedish_table_index]

# Extract table data
data = []
for row in swedish_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
swedish_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
swedish_df['Language'] = 'Swedish'
swedish_df
# Out:
#                        Title                       Genre  \
# 0           Barracuda Queens           Heist crime drama
# 1                       Tore  Coming-of-age comedy drama
# 2                       None                        None
# 3  The Helicopter Heist[139]                 Heist drama
#
#                  Premiere               Seasons    Runtime  \
# 0            June 5, 2023  1 season, 6 episodes  31–34 min
# 1        October 27, 2023  1 season, 6 episodes  29–34 min
# 2                    None                  None       None
# 3  November 22, 2024[140]                   TBA        TBA
#
#                                        Status Language
# 0  Season 2 due to premiere in 2025[137][138]  Swedish
# 1                                     Pending  Swedish
# 2                                        None  Swedish
# 3                                     Pending  Swedish

# %%
thai_table_index = 19
thai_table = tables[thai_table_index]

# Extract table data
data = []
for row in thai_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
thai_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
thai_df['Language'] = 'Thai'
thai_df
# Out:
#                      Title                    Genre           Premiere  \
# 0             Analog Squad             Family drama   December 7, 2023
# 1         Ready, Set, Love  Romantic mystery comedy  February 15, 2024
# 2            The Believers              Crime drama     March 27, 2024
# 3            Doctor Climax             Comedy drama      June 13, 2024
# 4      Master of the House                    Drama      July 18, 2024
# 5  Terror Tuesday: Extreme         Horror anthology    August 20, 2024
#
#                 Seasons    Runtime        Status Language
# 0  1 season, 8 episodes  55–70 min       Pending     Thai
# 1  1 season, 6 episodes  63–79 min       Pending     Thai
# 2  1 season, 9 episodes  37–59 min  Renewed[141]     Thai
# 3  1 season, 8 episodes  48–65 min       Pending     Thai
# 4  1 season, 7 episodes  44–62 min       Pending     Thai
# 5  1 season, 8 episodes  38–46 min       Pending     Thai

# %%
turkish_table_index = 20
turkish_table = tables[turkish_table_index]

# Extract table data
data = []
for row in turkish_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
turkish_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime', 'Status'])
turkish_df['Language'] = 'Turkish'
turkish_df
# Out:
#                                  Title            Genre           Premiere  \
# 0          Midnight at the Pera Palace            Drama      March 3, 2022
# 1  The Life and Movies of Erşan Kuneri           Sitcom       May 13, 2022
# 2                         Another Self            Drama      July 28, 2022
# 3                            Shahmaran          Fantasy   January 20, 2023
# 4                           The Tailor          Mystery        May 2, 2023
# 5                                Kübra         Thriller   January 18, 2024
# 6                  A Round of Applause            Drama  February 29, 2024
# 7                      Thank You, Next  Romantic comedy        May 9, 2024
#
#                   Seasons    Runtime  \
# 0    1 season, 8 episodes  40–47 min
# 1    1 season, 8 episodes  38–56 min
# 2  2 seasons, 16 episodes  45–67 min
# 3  2 seasons, 14 episodes  43–59 min
# 4  3 seasons, 23 episodes  28–48 min
# 5  2 seasons, 16 episodes  37–49 min
# 6    1 season, 6 episodes  26–37 min
# 7    1 season, 8 episodes  37–51 min
#
#                                               Status Language
# 0  Season 2 due to premiere on September 12, 2024...  Turkish
# 1                                       Renewed[144]  Turkish
# 2                                            Pending  Turkish
# 3                                            Pending  Turkish
# 4                                            Pending  Turkish
# 5                                            Pending  Turkish
# 6                                            Pending  Turkish
# 7                                       Renewed[145]  Turkish

# %%
other_table_index = 21
other_table = tables[other_table_index]

# Extract table data
data = []
for row in other_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
other_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime','Language','Status'])
other_df
# Out:
#                             Title                  Genre  \
# 0                      Baby Fever  Romantic comedy drama
# 1                          Kohrra            Crime drama
# 2               Ferry: The Series            Crime drama
# 3                         Olóládé                 Comedy
# 4            Replacing Chef Chico                  Drama
# 5  Aníkúlápó: Rise of the Spectre                  Drama
# 6                            Bros           Comedy drama
# 7                            None                   None
# 8         Billionaire Island[147]                  Drama
# 9               Blood Legacy[149]                  Drama
#
#                   Premiere                 Seasons    Runtime   Language  \
# 0             June 8, 2022  2 seasons, 12 episodes  27–35 min     Danish
# 1            July 15, 2023    1 season, 6 episodes  44–50 min    Punjabi
# 2         November 3, 2023    1 season, 8 episodes  36–51 min      Dutch
# 3        November 24, 2023    1 season, 6 episodes  36–50 min     Yoruba
# 4        November 24, 2023    1 season, 8 episodes  32–36 min   Filipino
# 5            March 1, 2024    1 season, 6 episodes  54–74 min     Yoruba
# 6           April 18, 2024    1 season, 8 episodes  29–43 min     Hebrew
# 7                     None                    None       None       None
# 8  September 12, 2024[148]                     TBA        TBA  Norwegian
# 9       September 20, 2024                     TBA        TBA       Zulu
#
#          Status
# 0       Pending
# 1  Renewed[146]
# 2       Pending
# 3       Pending
# 4       Pending
# 5       Pending
# 6       Pending
# 7          None
# 8       Pending
# 9       Pending

# %%
docuseries_table_index = 22
docuseries_table = tables[docuseries_table_index]

# Extract table data
data = []
for row in docuseries_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
docuseries_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime','Language','Status'])
docuseries_df
# Out:
#                                                 Title               Genre  \
# 0                               The Toys That Made Us        Toy industry
# 1                                  Somebody Feed Phil              Travel
# 2                         Formula 1: Drive to Survive              Sports
# 3   High on the Hog: How African American Cuisine ...        Food/history
# 4                                 Worst Roommate Ever          True crime
# 5                                          Full Swing              Sports
# 6                             Missing: Dead or Alive?          True crime
# 7                                          Encounters   Extraterrestrials
# 8                              Vasco Rossi: Living It     Music/biography
# 9                                           Get Gotti          True crime
# 10                                 Life on Our Planet              Nature
# 11                             Mysteries of the Faith            Religion
# 12                               Escaping Twin Flames               Cults
# 13                           How to Become a Mob Boss     Organized crime
# 14                  Bad Surgeon: Love Under the Knife          True crime
# 15                  World War II: From the Frontlines             History
# 16                              If I Were Luísa Sonza               Music
# 17                              Captains of the World              Sports
# 18                                 American Nightmare          True crime
# 19                          Six Nations: Full Contact              Sports
# 20                                 NASCAR: Full Speed              Sports
# 21                     Alexander: The Making of a God             History
# 22           American Conspiracy: The Octopus Murders          True crime
# 23           The Indrani Mukerjea Story: Buried Truth          True crime
# 24       ARA San Juan: The Submarine That Disappeared             History
# 25           Turning Point: The Bomb and the Cold War             History
# 26  From Dreams to Tragedy: The Fire That Shook Br...              Sports
# 27                                           Homicide          True crime
# 28                      Testament: The Story of Moses    History/Religion
# 29               Crime Scene Berlin: Nightlife Killer          True crime
# 30                           Files of the Unexplained          Paranormal
# 31                Ashley Madison: Sex, Lies & Scandal          True crime
# 32                           Toughest Forces on Earth            Military
# 33          Dancing for the Devil: The 7M TikTok Cult          True crime
# 34                Hitler and the Nazis: Evil on Trial             History
# 35  America's Sweethearts: Dallas Cowboys Cheerlea...              Sports
# 36                                  Kaulitz & Kaulitz               Music
# 37                                             Sprint              Sports
# 38                                           Receiver              Sports
# 39                                 LALIGA: All Access              Sports
# 37             July 2, 2024       1 season, 6 episodes  33–48 min     English
# 38            July 10, 2024       1 season, 8 episodes  52–62 min     English
# 39            July 15, 2024       1 season, 8 episodes  43–52 min     Spanish
# 40            July 17, 2024       1 season, 2 episodes  49–55 min     English
# 41          August 14, 2024       1 season, 3 episodes  51–54 min     English
# 42          August 21, 2024       1 season, 8 episodes  50–55 min     English
# 43          August 21, 2024       1 season, 6 episodes  30–49 min     English
# 44          August 28, 2024       1 season, 4 episodes  51–63 min     English
# 45                     None                       None       None        None
# 46        September 5, 2024                        TBA        TBA     Spanish
# 47  September 10, 2024[159]                        TBA        TBA     English
# 48       September 12, 2024  1 season, 3 episodes[135]        TBA     Spanish
# 49       September 12, 2024       1 season, 2 episodes        TBA     English
# 50       September 18, 2024                 5 episodes        TBA     English
# 51       September 25, 2024                 6 episodes        TBA     English
# 52     October 9, 2024[166]                        TBA        TBA     English
#
#                                                Status
# 0                        Renewed for seasons 4–5[150]
# 1                                        Renewed[151]
# 2                                             Pending
# 3                                             Pending
# 4                                             Pending
# 5                                             Pending
# 6                                        Renewed[152]
# 7                                             Pending
# 8                                             Pending
# 9                                             Pending
# 10                                       Renewed[153]
# 11                                            Pending
# 12                                            Pending
# 13                                            Pending
# 14                                            Pending
# 15                                            Pending
# 16                                            Pending
# 17                                            Pending
# 18                                            Pending
# 19                                            Pending
# 20                                            Pending
# 21                                            Pending
# 22                                            Pending
# 23                                            Pending
# 24                                            Pending
# 25                                            Pending
# 26                                            Pending
# 27                                            Pending
# 28                                            Pending
# 29                                            Pending
# 30                                            Pending
# 31                                            Pending
# 32                                            Pending
# 33                                            Pending
# 34                                            Pending
# 35                                            Pending
# 36                                       Renewed[154]
# 37  Season 2 due to premiere on November 13, 2024[...
# 38                                            Pending
# 39                                            Pending
# 40  New episodes due to premiere on October 25, 20...
# 41                                            Pending
# 42                                            Pending
# 43                                            Pending
# 44                                            Pending
# 45                                               None
# 46                                         Miniseries
# 47                                            Pending
# 48                                            Pending
# 49                                            Pending
# 50                                         Miniseries
# 51                                         Miniseries
# 52                                            Pending

# %%
reality_table_index = 23
reality_table = tables[reality_table_index]

# Extract table data
data = []
for row in reality_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
reality_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime','Language','Status'])
reality_df
# Out:
#                                        Title                        Genre  \
# 0                                  Queer Eye             Makeover reality
# 1                Car Masters: Rust to Riches                      Reality
# 2                             Selling Sunset                      Reality
# 3                              Rhythm + Flow            Music competition
# 4                                 The Circle          Reality competition
# 5                              Love Is Blind                  Dating show
# 6                          Too Hot to Handle                  Dating show
# 7                          Barbecue Showdown          Cooking competition
# 8          Fabulous Lives of Bollywood Wives                      Reality
# 9                      Love Is Blind: Brazil                  Dating show
# 10                             I Am Georgina                      Reality
# 11                               Is It Cake?           Baking competition
# 12                   Young, Famous & African                      Reality
# 13           The Ultimatum: Marry or Move On                  Dating show
# 14                      Love on the Spectrum                  Dating show
# 15                      Rhythm + Flow France            Music competition
# 16                            Selling the OC                      Reality
# 17                            Forever Queens                      Reality
# 11                                            Pending
# 12                                       Renewed[174]
# 13  Season 3 due to premiere in December 2024[175][6]
# 14                                       Renewed[176]
# 15                                            Pending
# 16                                            Pending
# 17                                            Pending
# 18               Season 3 due to premiere in 2024[75]
# 19                                            Pending
# 20                                            Pending
# 21                                       Renewed[177]
# 22           Season 2 due to premiere in 2024[79][80]
# 23  Season 2 due to premiere on September 4, 2024[...
# 24                                            Pending
# 25         Season 2 due to premiere in 2024[179][108]
# 26                                       Renewed[175]
# 27                                       Renewed[180]
# 28                                            Pending
# 29  Season 2 due to premiere in November 2024[181]...
# 30   Season 2 due to premiere in early 2025[183][182]
# 31                                       Renewed[184]
# 32                                            Pending
# 33                                            Pending
# 34                                            Pending
# 35                                            Pending
# 36                                            Pending
# 37                                       Renewed[137]
# 38                                            Pending
# 39                                            Pending
# 40                                            Pending
# 41                                            Pending
# 42                                            Pending
# 43                                            Pending
# 44                                            Pending
# 45                                            Pending
# 46                                            Pending
# 47                                            Pending
# 48                                       Renewed[185]
# 49                                            Pending
# 50                                            Pending
# 51                                            Pending
# 52                                            Pending
# 53                                       Renewed[186]
# 54                                            Pending
# 55                                            Pending
# 56                                               None
# 57                                            Pending
# 58                                            Pending
# 59                                            Pending

# %%
variety_table_index = 24
variety_table = tables[variety_table_index]

# Extract table data
data = []
for row in variety_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
variety_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime','Language','Status'])
variety_df
# Out:
#                                                Title  \
# 0  My Next Guest Needs No Introduction with David...
# 1                                  Last One Standing
# 2                                    Baby Animal Cam
# 3                  Dinner Time Live with David Chang
# 4             Risqué Business: Netherlands & Germany
# 5                        The Great Indian Kapil Show
# 6         John Mulaney Presents: Everybody's in L.A.
# 7                                               None
# 8     Live from the Other Side with Tyler Henry[192]
#
#                        Genre            Premiere                 Seasons  \
# 0                  Interview    January 12, 2018  5 seasons, 25 episodes
# 1  Crime comedy/variety show       March 8, 2022  3 seasons, 24 episodes
# 2                 Live event    October 12, 2023    1 season, 4 episodes
# 3     Cooking show/Talk show    January 25, 2024   1 season, 26 episodes
# 4                  Talk show   February 20, 2024    1 season, 6 episodes
# 5                  Talk show      March 30, 2024   1 season, 13 episodes
# 6       Live event/Talk show         May 3, 2024    1 season, 6 episodes
# 7                       None                None                    None
# 8       Paranormal/Talk show  September 17, 2024                     TBA
#
#        Runtime  Language            Status
# 0    41–58 min   English           Pending
# 1    30–54 min  Japanese           Pending
# 2  115–150 min   English           Pending
# 3    51–71 min   English  Season 1 ongoing
# 4    25–35 min    Korean           Pending
# 5    38–71 min     Hindi      Renewed[191]
# 6    61–85 min   English           Pending
# 7         None      None              None
# 8          TBA   English           Pending

# %%
continuation_table_index = 25
continuation_table = tables[continuation_table_index]

# Extract table data
data = []
for row in continuation_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
continuation_df = pd.DataFrame(data, columns=['Title', 'Genre','Previous network(s)', 'Premiere', 'Seasons', 'Runtime','Language','Status'])
continuation_df=continuation_df.drop('Previous network(s)',axis=1)
continuation_df
# Out:
#                                        Title  \
# 0                  Black Mirror (series 3–6)
# 1                          You (seasons 2–4)
# 2         Unsolved Mysteries (seasons 15–17)
# 3                    Cobra Kai (seasons 3–6)
# 4                   Blown Away (seasons 2–4)
# 5                 Kota Factory (seasons 2–3)
# 6                     The Mole (seasons 6–7)
# 7                       Girls5eva (season 3)
# 8  From Me to You: Kimi ni Todoke (season 3)
#
#                               Genre            Premiere  \
# 0         Science fiction anthology    October 21, 2016
# 1            Psychological thriller   December 26, 2019
# 2                        Docuseries        July 1, 2020
# 3  Martial arts/action comedy drama     January 1, 2021
# 4                           Reality    January 22, 2021
# 5                      Comedy drama  September 24, 2021
# 6               Reality competition     October 7, 2022
# 7                            Comedy      March 14, 2024
# 8                             Anime      August 1, 2024
#
#                   Seasons    Runtime  Language  \
# 0  4 seasons, 20 episodes  40–89 min   English
# 1  3 seasons, 30 episodes  41–58 min   English
# 2  4 volumes, 26 episodes  36–54 min   English
# 3  4 seasons, 35 episodes  27–48 min   English
# 4  3 seasons, 30 episodes  25–36 min   English
# 5  2 seasons, 10 episodes  31–61 min     Hindi
# 6  2 seasons, 20 episodes  34–51 min   English
# 7    1 season, 6 episodes  24–28 min   English
# 8    1 season, 6 episodes  14–72 min  Japanese
#
#                                               Status
# 0              Season 7 due to premiere in 2025[193]
# 1                      Renewed for final season[194]
# 2           Volume 5 due to premiere in Q4 2024[195]
# 3  Final season part 2 due to premiere on Novembe...
# 4                                            Pending
# 5                                            Pending
# 6                                            Pending
# 7                                            Pending
# 8                                            Pending

# %%
episodic_table_index = 26
episodic_table = tables[episodic_table_index]

# Extract table data
data = []
for row in episodic_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
episodic_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime','Language','Status'])
episodic_df
# Out:
#                         Title                    Genre           Premiere  \
# 0   Squid Game: The Challenge  Escape room competition  November 22, 2023
# 1  Cobra Kai: Inside the Dojo        Behind the scenes      July 18, 2024
#
#                  Seasons    Runtime Language            Status
# 0  1 season, 10 episodes  40–57 min  English      Renewed[199]
# 1    1 season, 1 episode     11 min  English  Season 1 ongoing

# %%
regi_table_index = 27
regi_table = tables[regi_table_index]

# Extract table data
data = []
for row in regi_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
regi_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere', 'Seasons', 'Runtime','Language','Netflix exc region','Status'])
regi_df = regi_df.drop('Netflix exc region',axis=1)
regi_df
# Out:
#                          Title                                     Genre  \
# 0                       Arcane  Adult animated steampunk science fantasy
# 1   Bad Exorcist (seasons 3–5)              Adult animated horror comedy
# 2      Ninjago: Dragons Rising                           Animated comedy
# 3  Ronja the Robber's Daughter                     Coming-of-age fantasy
#
#            Premiere                 Seasons    Runtime Language  \
# 0  November 6, 2021    1 season, 9 episodes  39–44 min  English
# 1  October 14, 2022  2 seasons, 39 episodes  10–17 min   Polish
# 2      June 1, 2023  2 seasons, 30 episodes  22–23 min  English
# 3    March 28, 2024    1 season, 6 episodes  42–45 min  Swedish
#
#                                               Status
# 0  Final season due to premiere in November 2024[...
# 1                                            Pending
# 2    Season 2 part 2 due to premiere October 3, 2024
# 3       Season 1 part 2 due to premiere in 2024[202]

# %%
coprod_table_index = 28
coprod_table = tables[coprod_table_index]

# Extract table data
data = []
for row in coprod_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
coprod_df = pd.DataFrame(data, columns=['Title', 'Genre','Partner/Country', 'Premiere', 'Seasons', 'Runtime','Language','Netflix exc region','Status'])
coprod_df=coprod_df.drop(['Partner/Country','Netflix exc region'],axis=1) 
coprod_df
# Out:
#                                                Title  \
# 0                                   Single's Inferno
# 1  The Parisian Agency: Exclusive Properties (sea...
# 2                          Tour de France: Unchained
# 3                                I Woke Up a Vampire
#
#                                  Genre           Premiere  \
# 0                          Dating show  December 18, 2021
# 1          Property management reality      March 3, 2022
# 2                    Sports docuseries       June 8, 2023
# 3  Family supernatural comedy thriller   October 17, 2023
#
#                   Seasons    Runtime Language  \
# 0  3 seasons, 29 episodes  56–90 min   Korean
# 1  3 seasons, 24 episodes  51–70 min   French
# 2  2 seasons, 16 episodes  34–49 min   French
# 3  2 seasons, 16 episodes  23–27 min  English
#
#                                               Status
# 0  Season 4 due to premiere in January 2025[204][...
# 1                                            Pending
# 2                                       Renewed[205]
# 3                                            Pending

# %%
conti_table_index = 29
conti_table = tables[conti_table_index]

# Extract table data
data = []
for row in conti_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
conti_df = pd.DataFrame(data, columns=['Title', 'Genre','Previous network(s)', 'Premiere', 'Seasons', 'Runtime','Language','Netflix excl region','Status'])
conti_df=conti_df.drop(['Previous network(s)','Netflix excl region'],axis=1) 
conti_df
# Out:
#                        Title         Genre           Premiere  \
# 0  Skam Italia (seasons 4–6)    Teen drama       May 15, 2020
# 1   CoComelon (seasons 6–10)     Preschool  September 5, 2022
# 2        Pernille (season 4)  Comedy drama     August 8, 2024
#
#                   Seasons    Runtime   Language        Status
# 0  3 seasons, 30 episodes  20–40 min    Italian       Pending
# 1  5 seasons, 11 episodes  46–64 min    English       Pending
# 2    1 season, 6 episodes  26–28 min  Norwegian  Renewed[206]

# %%
upcomingDrama_table_index = 30
upcomingDrama_table = tables[upcomingDrama_table_index]

# Extract table data
data = []
for row in upcomingDrama_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingDrama_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingDrama_df['Seasons'] = 'Unknown'
upcomingDrama_df['Runtime'] = 'Unknown'
upcomingDrama_df['Language'] = 'English'
upcomingDrama_df['Status'] = 'Upcoming'
upcomingDrama_df
# Out:
#                                          Title  \
# 0                  American Primeval[207][208]
# 1                               Baby Farm[209]
# 2                        Black Doves[211][212]
# 3                     To Kill a Monkey[6][213]
# 4                        Adolescence[214][215]
# 5                              The Choice[216]
# 6                            The Undertow[217]
# 7                             The Witness[214]
# 8             The Abandons[218][219][220][221]
# 9                     Apple Cider Vinegar[222]
# 10                                 Atomic[223]
# 11   Baahubali: Before the Beginning[224][225]
# 12                        The Beast in Me[226]
# 13                   Beauty in Black[227][228]
# 14                                    BET[229]
# 15                 Black Rabbit[230][231][232]
# 16                           The Boroughs[233]
# 17                                 Covers[234]
# 18           Death by Lightning[235][236][237]
# 19                      Department Q[211][238]
# 20                      Forever[239][240][241]
# 21                              Grown Ups[214]
# 22                             His & Hers[242]
# 23                      House of Guinness[214]
# 24      How to Get to Heaven from Belfast[243]
# 25                How to Kill Your Family[244]
# 26                                Legends[245]
# 27                  Man on Fire[246][247][248]
# 41                  Biopic miniseries        TBA  Unknown  Unknown  English
# 42             Crime drama miniseries        TBA  Unknown  Unknown  English
# 43                              Drama        TBA  Unknown  Unknown  English
# 44                              Drama        TBA  Unknown  Unknown  English
# 45                Thriller miniseries        TBA  Unknown  Unknown  English
# 46      Political thriller miniseries        TBA  Unknown  Unknown  English
#
#       Status
# 0   Upcoming
# 1   Upcoming
# 2   Upcoming
# 3   Upcoming
# 4   Upcoming
# 5   Upcoming
# 6   Upcoming
# 7   Upcoming
# 8   Upcoming
# 9   Upcoming
# 10  Upcoming
# 11  Upcoming
# 12  Upcoming
# 13  Upcoming
# 14  Upcoming
# 15  Upcoming
# 16  Upcoming
# 17  Upcoming
# 18  Upcoming
# 19  Upcoming
# 20  Upcoming
# 21  Upcoming
# 22  Upcoming
# 23  Upcoming
# 24  Upcoming
# 25  Upcoming
# 26  Upcoming
# 27  Upcoming
# 28  Upcoming
# 29  Upcoming
# 30  Upcoming
# 31  Upcoming
# 32  Upcoming
# 33  Upcoming
# 34  Upcoming
# 35  Upcoming
# 36  Upcoming
# 37  Upcoming
# 38  Upcoming
# 39  Upcoming
# 40  Upcoming
# 41  Upcoming
# 42  Upcoming
# 43  Upcoming
# 44  Upcoming
# 45  Upcoming
# 46  Upcoming

# %%
upcomingComedy_table_index = 31
upcomingComedy_table = tables[upcomingComedy_table_index]

# Extract table data
data = []
for row in upcomingComedy_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingComedy_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingComedy_df['Seasons'] = 'Unknown'
upcomingComedy_df['Runtime'] = 'Unknown'
upcomingComedy_df['Language'] = 'English'
upcomingComedy_df['Status'] = 'Upcoming'
upcomingComedy_df
# Out:
#                                 Title                   Genre  \
# 0       A Man on the Inside[282][283]            Crime comedy
# 1         No Good Deed[285][286][287]             Dark comedy
# 2   Running Point[288][289][290][291]           Sports comedy
# 3                      The Corps[292]   Military comedy drama
# 4     The Four Seasons[293][294][295]         Romantic comedy
# 5                           Golf[296]           Sports comedy
# 6     Sirens[297][298][299][300][301]  Dark comedy miniseries
# 7                  Too Much[302][303]         Romantic comedy
# 8  Untitled Leanne Morgan series[304]                  Sitcom
# 9     Untitled Tom Segura series[305]             Dark comedy
#
#                 Premiere  Seasons  Runtime Language    Status
# 0  November 2024[6][284]  Unknown  Unknown  English  Upcoming
# 1                2024[6]  Unknown  Unknown  English  Upcoming
# 2              2025[291]  Unknown  Unknown  English  Upcoming
# 3                    TBA  Unknown  Unknown  English  Upcoming
# 4                    TBA  Unknown  Unknown  English  Upcoming
# 5                    TBA  Unknown  Unknown  English  Upcoming
# 6                    TBA  Unknown  Unknown  English  Upcoming
# 7                    TBA  Unknown  Unknown  English  Upcoming
# 8                    TBA  Unknown  Unknown  English  Upcoming
# 9                    TBA  Unknown  Unknown  English  Upcoming

# %%
upcomingAnimation_table_index = 32
upcomingAnimation_table = tables[upcomingAnimation_table_index]

# Extract table data
data = []
for row in upcomingAnimation_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingAnimation_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingAnimation_df['Seasons'] = 'Unknown'
upcomingAnimation_df['Runtime'] = 'Unknown'
upcomingAnimation_df['Language'] = 'English'
upcomingAnimation_df['Status'] = 'Upcoming'
upcomingAnimation_df
# Out:
#                                            Title                     Genre  \
# 0                          Long Story Short[306]                    Comedy
# 1                              Gears of War[307]  Military science fiction
# 2                     Ghostbusters[308][71][309]             Horror comedy
# 3                             The Undervale[310]                    Comedy
# 4  Untitled Stranger Things animated series[311]    Science fiction horror
#
#   Premiere  Seasons  Runtime Language    Status
# 0     2025  Unknown  Unknown  English  Upcoming
# 1      TBA  Unknown  Unknown  English  Upcoming
# 2      TBA  Unknown  Unknown  English  Upcoming
# 3      TBA  Unknown  Unknown  English  Upcoming
# 4      TBA  Unknown  Unknown  English  Upcoming

# %%
upcomingAnime_table_index = 33
upcomingAnime_table = tables[upcomingAnime_table_index]

# Extract table data
data = []
for row in upcomingAnime_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingAnime_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingAnime_df['Seasons'] = 'Unknown'
upcomingAnime_df['Runtime'] = 'Unknown'
upcomingAnime_df['Language'] = 'English'
upcomingAnime_df['Status'] = 'Upcoming'
upcomingAnime_df
# Out:
#                                     Title                        Genre  \
# 0                 Devil May Cry[312][313]          Dark fantasy action
# 1                           Moonrise[315]              Science fiction
# 2                          Tokyo Override              Science fiction
# 3                          Leviathan[318]             Historical drama
# 4  Army of the Dead: Lost Vegas[319][320]                       Horror
# 5            Beat & Motion[321][322][323]                Slice of life
# 6                 Lady Napoleon[324][325]                       Action
# 7                      The One Piece[326]  Adventure / science fantasy
# 8             Stranger Things: Tokyo[327]       Science fiction horror
#
#     Premiere  Seasons  Runtime Language    Status
# 0  2024[314]  Unknown  Unknown  English  Upcoming
# 1  2024[316]  Unknown  Unknown  English  Upcoming
# 2  2024[317]  Unknown  Unknown  English  Upcoming
# 3  2025[317]  Unknown  Unknown  English  Upcoming
# 4        TBA  Unknown  Unknown  English  Upcoming
# 5        TBA  Unknown  Unknown  English  Upcoming
# 6        TBA  Unknown  Unknown  English  Upcoming
# 7        TBA  Unknown  Unknown  English  Upcoming
# 8        TBA  Unknown  Unknown  English  Upcoming

# %%
upcomingKF_table_index = 34
upcomingKF_table = tables[upcomingKF_table_index]

# Extract table data
data = []
for row in upcomingKF_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingKF_df = pd.DataFrame(data, columns=['Title', 'Genre','Language', 'Premiere'])
upcomingKF_df['Seasons'] = 'Unknown'
upcomingKF_df['Runtime'] = 'Unknown'
upcomingKF_df['Status'] = 'Upcoming'
upcomingKF_df
# Out:
#                                            Title                        Genre  \
# 0       Jentry Chau vs. The Underworld[328][329]       Supernatural adventure
# 1         Astérix and Obélix: The Big Fight[330]  Historical action adventure
# 2                             Motel Transylvania                Horror comedy
# 3                            Wolf King[332][317]       Epic fantasy adventure
# 4                       Horton Hears a Who![333]                    Preschool
# 5                                   Mafalda[135]                       Comedy
# 6   One Fish, Two Fish, Red Fish, Blue Fish[333]                    Preschool
# 7                           The Seven Bears[332]               Fantasy comedy
# 8                Untitled Rebel Moon series[334]                  Space opera
# 9          Untitled The Witcher series[335][336]                      Fantasy
# 10                          Wacky Wednesday[333]                    Preschool
#
#    Language   Premiere  Seasons  Runtime    Status
# 0   English    2024[6]  Unknown  Unknown  Upcoming
# 1    French  2025[331]  Unknown  Unknown  Upcoming
# 2   English  2025[317]  Unknown  Unknown  Upcoming
# 3   English  2025[317]  Unknown  Unknown  Upcoming
# 4   English        TBA  Unknown  Unknown  Upcoming
# 5   Spanish        TBA  Unknown  Unknown  Upcoming
# 6   English        TBA  Unknown  Unknown  Upcoming
# 7       TBA        TBA  Unknown  Unknown  Upcoming
# 8   English        TBA  Unknown  Unknown  Upcoming
# 9   English        TBA  Unknown  Unknown  Upcoming
# 10  English        TBA  Unknown  Unknown  Upcoming

# %%
upcomingDutch_table_index = 35
upcomingDutch_table = tables[upcomingDutch_table_index]

# Extract table data
data = []
for row in upcomingDutch_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingDutch_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingDutch_df['Seasons'] = 'Unknown'
upcomingDutch_df['Runtime'] = 'Unknown'
upcomingDutch_df['Language'] = 'Dutch'
upcomingDutch_df['Status'] = 'Upcoming'
upcomingDutch_df
# Out:
#                    Title     Genre   Premiere  Seasons  Runtime Language  \
# 0  Amsterdam Empire[337]  Thriller  2025[338]  Unknown  Unknown    Dutch
# 1  Football Parents[339]    Comedy       2025  Unknown  Unknown    Dutch
# 2     Roosters[340][126]    Comedy       2025  Unknown  Unknown    Dutch
#
#      Status
# 0  Upcoming
# 1  Upcoming
# 2  Upcoming

# %%
upcomingFrench_table_index = 36
upcomingFrench_table = tables[upcomingFrench_table_index]

# Extract table data
data = []
for row in upcomingFrench_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingFrench_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingFrench_df['Seasons'] = 'Unknown'
upcomingFrench_df['Runtime'] = 'Unknown'
upcomingFrench_df['Language'] = 'French'
upcomingFrench_df['Status'] = 'Upcoming'
upcomingFrench_df
# Out:
#                                   Title     Genre Premiere  Seasons  Runtime  \
# 0                          La Cage[341]     Drama     2024  Unknown  Unknown
# 1                Burn(es) Out[342][343]    Comedy      TBA  Unknown  Unknown
# 2                       Super Mâle[126]    Comedy      TBA  Unknown  Unknown
# 3  Untitled Isabelle Adjani series[337]  Thriller      TBA  Unknown  Unknown
#
#   Language    Status
# 0   French  Upcoming
# 1   French  Upcoming
# 2   French  Upcoming
# 3   French  Upcoming

# %%
upcomingGerman_table_index = 37
upcomingGerman_table = tables[upcomingGerman_table_index]

# Extract table data
data = []
for row in upcomingGerman_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingGerman_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingGerman_df['Seasons'] = 'Unknown'
upcomingGerman_df['Runtime'] = 'Unknown'
upcomingGerman_df['Language'] = 'German'
upcomingGerman_df['Status'] = 'Upcoming'
upcomingGerman_df
# Out:
#                                      Title                     Genre Premiere  \
# 0                       Cassandra[344][79]  Science fiction thriller     2024
# 1                 Plötzlich Kanzlerin[345]              Comedy drama     2024
# 2  Untitled adaptation of Alpha Males[126]                    Comedy      TBA
#
#    Seasons  Runtime Language    Status
# 0  Unknown  Unknown   German  Upcoming
# 1  Unknown  Unknown   German  Upcoming
# 2  Unknown  Unknown   German  Upcoming

# %%
upcomingHindi_table_index = 38
upcomingHindi_table = tables[upcomingHindi_table_index]

# Extract table data
data = []
for row in upcomingHindi_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingHindi_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingHindi_df['Seasons'] = 'Unknown'
upcomingHindi_df['Runtime'] = 'Unknown'
upcomingHindi_df['Language'] = 'Hindi'
upcomingHindi_df['Status'] = 'Upcoming'
upcomingHindi_df
# Out:
#                                      Title            Genre Premiere  Seasons  \
# 0           Khakee: The Bengal Chapter[87]   Crime thriller     2024  Unknown
# 1                        Dabba Cartel[346]   Crime thriller      TBA  Unknown
# 2  Rakt Bramhand – The Bloody Kingdom[347]   Action fantasy      TBA  Unknown
# 3                          The Royals[348]  Romantic comedy      TBA  Unknown
#
#    Runtime Language    Status
# 0  Unknown    Hindi  Upcoming
# 1  Unknown    Hindi  Upcoming
# 2  Unknown    Hindi  Upcoming
# 3  Unknown    Hindi  Upcoming

# %%
upcomingItalian_table_index = 39
upcomingItalian_table = tables[upcomingItalian_table_index]

# Extract table data
data = []
for row in upcomingItalian_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingItalian_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingItalian_df['Seasons'] = 'Unknown'
upcomingItalian_df['Runtime'] = 'Unknown'
upcomingItalian_df['Language'] = 'Italian'
upcomingItalian_df['Status'] = 'Upcoming'
upcomingItalian_df
# Out:
#                             Title                   Genre   Premiere  Seasons  \
# 0            The Leopard[349][99]                   Drama  2024[102]  Unknown
# 1           Maschi veri[350][126]                  Comedy       2025  Unknown
# 2          A.C.A.B. La serie[351]             Crime drama        TBA  Unknown
# 3                 Adorazione[352]     Coming of age drama        TBA  Unknown
# 4                  Il Mostro[353]  Crime drama miniseries        TBA  Unknown
# 5                  Lotto Gang[99]                  Comedy        TBA  Unknown
# 6                Mrs Playmen[354]                  Biopic        TBA  Unknown
# 7                    Nemesis[355]                   Drama        TBA  Unknown
# 8                       Sara[356]             Crime drama        TBA  Unknown
# 9  Storia della mia famiglia[352]                   Drama        TBA  Unknown
#
#    Runtime Language    Status
# 0  Unknown  Italian  Upcoming
# 1  Unknown  Italian  Upcoming
# 2  Unknown  Italian  Upcoming
# 3  Unknown  Italian  Upcoming
# 4  Unknown  Italian  Upcoming
# 5  Unknown  Italian  Upcoming
# 6  Unknown  Italian  Upcoming
# 7  Unknown  Italian  Upcoming
# 8  Unknown  Italian  Upcoming
# 9  Unknown  Italian  Upcoming

# %%
upcomingJapanese_table_index = 40
upcomingJapanese_table = tables[upcomingJapanese_table_index]

# Extract table data
data = []
for row in upcomingJapanese_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingJapanese_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingJapanese_df['Seasons'] = 'Unknown'
upcomingJapanese_df['Runtime'] = 'Unknown'
upcomingJapanese_df['Language'] = 'Japanese'
upcomingJapanese_df['Status'] = 'Upcoming'
upcomingJapanese_df
# Out:
#                       Title                   Genre Premiere  Seasons  \
# 0          Glass Heart[357]             Music drama     2025  Unknown
# 1  Romantics Anonymous[358]         Romantic comedy     2025  Unknown
# 2          Human Vapor[359]  Science fiction horror      TBA  Unknown
# 3            Soul Mate[360]          Romantic drama      TBA  Unknown
#
#    Runtime  Language    Status
# 0  Unknown  Japanese  Upcoming
# 1  Unknown  Japanese  Upcoming
# 2  Unknown  Japanese  Upcoming
# 3  Unknown  Japanese  Upcoming

# %%
upcomingKorean_table_index = 41
upcomingKorean_table = tables[upcomingKorean_table_index]

# Extract table data
data = []
for row in upcomingKorean_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingKorean_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingKorean_df['Seasons'] = 'Unknown'
upcomingKorean_df['Runtime'] = 'Unknown'
upcomingKorean_df['Language'] = 'Korean'
upcomingKorean_df['Status'] = 'Upcoming'
upcomingKorean_df
# Out:
#                                   Title             Genre   Premiere  Seasons  \
# 0                        Hong Rang[361]      Period drama  2024[362]  Unknown
# 1                     Mr. Plankton[111]   Romantic comedy       2024  Unknown
# 2                        The Trunk[363]          Thriller  2024[111]  Unknown
# 3   When Life Gives You Tangerines[364]    Romantic drama  2024[365]  Unknown
# 4                             Aema[366]  Historical drama        TBA  Unknown
# 5        All the Love You Wish For[367]   Romantic comedy        TBA  Unknown
# 6     Can This Love Be Translated?[368]   Romantic comedy        TBA  Unknown
# 7                          Cashero[369]         Superhero        TBA  Unknown
# 8                            Karma[370]    Crime thriller        TBA  Unknown
# 9                   Mercy for None[371]          Thriller        TBA  Unknown
# 10         The Price of Confession[372]  Mystery thriller        TBA  Unknown
# 11                         Trigger[373]   Action thriller        TBA  Unknown
# 12                       Two Women[374]    Romantic drama        TBA  Unknown
#
#     Runtime Language    Status
# 0   Unknown   Korean  Upcoming
# 1   Unknown   Korean  Upcoming
# 2   Unknown   Korean  Upcoming
# 3   Unknown   Korean  Upcoming
# 4   Unknown   Korean  Upcoming
# 5   Unknown   Korean  Upcoming
# 6   Unknown   Korean  Upcoming
# 7   Unknown   Korean  Upcoming
# 8   Unknown   Korean  Upcoming
# 9   Unknown   Korean  Upcoming
# 10  Unknown   Korean  Upcoming
# 11  Unknown   Korean  Upcoming
# 12  Unknown   Korean  Upcoming

# %%
upcomingMandarin_table_index = 42
upcomingMandarin_table = tables[upcomingMandarin_table_index]

# Extract table data
data = []
for row in upcomingMandarin_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingMandarin_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingMandarin_df['Seasons'] = 'Unknown'
upcomingMandarin_df['Runtime'] = 'Unknown'
upcomingMandarin_df['Language'] = 'Mandarin'
upcomingMandarin_df['Status'] = 'Upcoming'
upcomingMandarin_df
# Out:
#                              Title            Genre Premiere  Seasons  \
# 0            Agent from Above[375]          Fantasy      TBA  Unknown
# 1              Forget You Not[376]     Comedy drama      TBA  Unknown
# 2  Million-follower Detective[377]   Crime thriller      TBA  Unknown
# 3             The Nipple Talk[375]  Romantic comedy      TBA  Unknown
# 4             The Resurrected[378]         Thriller      TBA  Unknown
#
#    Runtime  Language    Status
# 0  Unknown  Mandarin  Upcoming
# 1  Unknown  Mandarin  Upcoming
# 2  Unknown  Mandarin  Upcoming
# 3  Unknown  Mandarin  Upcoming
# 4  Unknown  Mandarin  Upcoming

# %%
upcomingNorwegian_table_index = 43
upcomingNorwegian_table = tables[upcomingNorwegian_table_index]

# Extract table data
data = []
for row in upcomingNorwegian_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingNorwegian_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingNorwegian_df['Seasons'] = 'Unknown'
upcomingNorwegian_df['Runtime'] = 'Unknown'
upcomingNorwegian_df['Language'] = 'Norwegian'
upcomingNorwegian_df['Status'] = 'Upcoming'
upcomingNorwegian_df
# Out:
#                            Title         Genre Premiere  Seasons  Runtime  \
# 0  Detective Hole[379][380][137]   Crime drama     2026  Unknown  Unknown
# 1        The New Force[380][137]  Period drama     2026  Unknown  Unknown
# 2                  La Palma[381]         Drama      TBA  Unknown  Unknown
#
#     Language    Status
# 0  Norwegian  Upcoming
# 1  Norwegian  Upcoming
# 2  Norwegian  Upcoming

# %%
upcomingPolish_table_index = 44
upcomingPolish_table = tables[upcomingPolish_table_index]

# Extract table data
data = []
for row in upcomingPolish_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingPolish_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingPolish_df['Seasons'] = 'Unknown'
upcomingPolish_df['Runtime'] = 'Unknown'
upcomingPolish_df['Language'] = 'Polish'
upcomingPolish_df['Status'] = 'Upcoming'
upcomingPolish_df
# Out:
#                          Title    Genre   Premiere  Seasons  Runtime Language  \
# 0               Heweliusz[382]    Drama  2025[383]  Unknown  Unknown   Polish
# 1  Go Ahead, Brother[384][385]   Comedy        TBA  Unknown  Unknown   Polish
# 2           Just One Look[386]  Mystery        TBA  Unknown  Unknown   Polish
# 3     Mothers of Penguins[384]    Drama        TBA  Unknown  Unknown   Polish
# 4             Project UFO[384]    Drama        TBA  Unknown  Unknown   Polish
#
#      Status
# 0  Upcoming
# 1  Upcoming
# 2  Upcoming
# 3  Upcoming
# 4  Upcoming

# %%
upcomingSpanish_table_index = 45
upcomingSpanish_table = tables[upcomingSpanish_table_index]

# Extract table data
data = []
for row in upcomingSpanish_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingSpanish_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingSpanish_df['Seasons'] = 'Unknown'
upcomingSpanish_df['Runtime'] = 'Unknown'
upcomingSpanish_df['Language'] = 'Spanish'
upcomingSpanish_df['Status'] = 'Upcoming'
upcomingSpanish_df
# Out:
#                                                 Title                   Genre  \
# 0                       Bienvenidos a la familia[387]                   Drama
# 1                                      Celda 211[388]  Crime drama miniseries
# 2                                 Gringo Hunters[388]          Crime thriller
# 3                       Las hermanas Guerra[389][388]                   Drama
# 4                                    Las muertas[388]             Crime drama
# 5                           Nadie nos vió partir[388]        Drama miniseries
# 6             One Hundred Years of Solitude[390][391]                   Drama
# 7                                   Para siempre[387]                   Drama
# 8                                    Caught[392][393]     Thriller miniseries
# 9                              The Eternaut[394][395]         Science fiction
# 10                                          1992[396]                Thriller
# 11                                Animal Salvaje[397]       Comedy miniseries
# 12                       Asalto al Banco Central[398]                   Heist
# 13                             The Gardener[399][400]                Thriller
# 14                       El refugio atómico[401][402]  Post-apocalyptic drama
# 15                              En el barro[403][135]                   Drama
# 16              La última noche en Tremore Beach[404]     Thriller miniseries
# 17                                        Legado[405]                   Drama
# 18                               Los maldiciones[135]      Political thriller
# 19                         Manual para señoritas[406]            Period drama
# 20                                        Olympo[407]              Teen drama
# 21                                      Salvador[408]                   Drama
# 22                        Serpientes y Escaleras[409]                  Comedy
# 23                          Superestar[410][411][412]            Music biopic
# 24  Untitled adaptation of Claudia Piñeiro's El ti...        Drama miniseries
#
#      Premiere  Seasons  Runtime Language    Status
# 0        2024  Unknown  Unknown  Spanish  Upcoming
# 1        2024  Unknown  Unknown  Spanish  Upcoming
# 2        2024  Unknown  Unknown  Spanish  Upcoming
# 3        2024  Unknown  Unknown  Spanish  Upcoming
# 4        2024  Unknown  Unknown  Spanish  Upcoming
# 5        2024  Unknown  Unknown  Spanish  Upcoming
# 6     2024[6]  Unknown  Unknown  Spanish  Upcoming
# 7        2024  Unknown  Unknown  Spanish  Upcoming
# 8   2025[135]  Unknown  Unknown  Spanish  Upcoming
# 9   2025[135]  Unknown  Unknown  Spanish  Upcoming
# 10        TBA  Unknown  Unknown  Spanish  Upcoming
# 11        TBA  Unknown  Unknown  Spanish  Upcoming
# 12        TBA  Unknown  Unknown  Spanish  Upcoming
# 13        TBA  Unknown  Unknown  Spanish  Upcoming
# 14        TBA  Unknown  Unknown  Spanish  Upcoming
# 15        TBA  Unknown  Unknown  Spanish  Upcoming
# 16        TBA  Unknown  Unknown  Spanish  Upcoming
# 17        TBA  Unknown  Unknown  Spanish  Upcoming
# 18        TBA  Unknown  Unknown  Spanish  Upcoming
# 19        TBA  Unknown  Unknown  Spanish  Upcoming
# 20        TBA  Unknown  Unknown  Spanish  Upcoming
# 21        TBA  Unknown  Unknown  Spanish  Upcoming
# 22        TBA  Unknown  Unknown  Spanish  Upcoming
# 23        TBA  Unknown  Unknown  Spanish  Upcoming
# 24        TBA  Unknown  Unknown  Spanish  Upcoming

# %%
upcomingSwedish_table_index = 46
upcomingSwedish_table = tables[upcomingSwedish_table_index]

# Extract table data
data = []
for row in upcomingSwedish_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingSwedish_df = pd.DataFrame(data, columns=['Title', 'Genre', 'Premiere'])
upcomingSwedish_df['Seasons'] = 'Unknown'
upcomingSwedish_df['Runtime'] = 'Unknown'
upcomingSwedish_df['Language'] = 'Swedish'
upcomingSwedish_df['Status'] = 'Upcoming'
upcomingSwedish_df
# Out:
#                                Title        Genre Premiere  Seasons  Runtime  \
# 0              The Breakthrough[139]  Crime drama     2024  Unknown  Unknown
# 1  Diary of a Ditched Girl[380][137]        Drama     2025  Unknown  Unknown
# 2                The Glass Dome[139]  Crime drama      TBA  Unknown  Unknown
#
#   Language    Status
# 0  Swedish  Upcoming
# 1  Swedish  Upcoming
# 2  Swedish  Upcoming

# %%
upcomingOtherLang_table_index = 47
upcomingOtherLang_table = tables[upcomingOtherLang_table_index]

# Extract table data
data = []
for row in upcomingOtherLang_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingOtherLang_df = pd.DataFrame(data, columns=['Title', 'Genre','Language', 'Premiere'])
upcomingOtherLang_df['Seasons'] = 'Unknown'
upcomingOtherLang_df['Runtime'] = 'Unknown'
upcomingOtherLang_df['Status'] = 'Upcoming'
upcomingOtherLang_df
# Out:
#                                  Title                      Genre    Language  \
# 0                            Asaf[413]                      Drama     Turkish
# 1                      Candelária[122]           Drama miniseries  Portuguese
# 2              Echoes of the Past[414]                Crime drama      Arabic
# 3                        The Town[413]                Crime drama     Turkish
# 4                 Don't Come Home[415]                     Horror        Thai
# 5   Jo Bachay Hain Sang Samait Lo[416]                      Drama        Urdu
# 6                      The Legend[417]                Crime drama      Danish
# 7                          Pssica[418]           Drama miniseries  Portuguese
# 8                      Reservatet[139]                Crime drama      Danish
# 9                        Subteran[419]                Crime drama    Romanian
# 10                 Tomorrow and I[415]  Science fiction anthology        Thai
#
#    Premiere  Seasons  Runtime    Status
# 0      2024  Unknown  Unknown  Upcoming
# 1      2024  Unknown  Unknown  Upcoming
# 2      2024  Unknown  Unknown  Upcoming
# 3      2024  Unknown  Unknown  Upcoming
# 4       TBA  Unknown  Unknown  Upcoming
# 5       TBA  Unknown  Unknown  Upcoming
# 6       TBA  Unknown  Unknown  Upcoming
# 7       TBA  Unknown  Unknown  Upcoming
# 8       TBA  Unknown  Unknown  Upcoming
# 9       TBA  Unknown  Unknown  Upcoming
# 10      TBA  Unknown  Unknown  Upcoming

# %%
upcomingDoc_table_index = 48
upcomingDoc_table = tables[upcomingDoc_table_index]

# Extract table data
data = []
for row in upcomingDoc_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingDoc_df = pd.DataFrame(data, columns=['Title', 'Genre','Language', 'Premiere'])
upcomingDoc_df['Seasons'] = 'Unknown'
upcomingDoc_df['Runtime'] = 'Unknown'
upcomingDoc_df['Status'] = 'Upcoming'
upcomingDoc_df
# Out:
#                                                 Title  \
# 0         The Greatest Rivalry: India vs Pakistan[87]
# 1                                     Our Oceans[420]
# 2                          Pinzner: German Hitman[79]
# 3                                    Shirin David[79]
# 4          Untitled 2004 World Series docuseries[421]
# 5   Untitled United States men's national basketba...
# 6                                       Critical[423]
# 7                                     F1 Academy[424]
# 8                                Our Water World[420]
# 9                       Millennium Diamond Heist[425]
# 10                  Alcaraz, the Docuseries[426][427]
# 11                             Famous Last Words[428]
# 12                          Hunting Gary Glitter[429]
# 13                                Jack Unterweger[79]
# 14                                  This Blew Up[430]
# 15        Untitled 2016 Bitfinex hack docuseries[431]
# 16               Untitled Barry Hearn docuseries[432]
# 17            Untitled Boston Red Sox docuseries[421]
# 18            Untitled Carmen Cervera docuseries[410]
# 19            Untitled Dallas Cowboys docuseries[422]
# 20  Untitled Gilgo Beach serial killings docuserie...
# 21             Untitled Gordon Ramsay docuseries[434]
# 22              Untitled John O'Keefe docuseries[435]
# 23        Untitled Meghan Markle docuseries[436][437]
# 24                 Untitled polo docuseries[436][437]
# 25                 Untitled Take That docuseries[438]
# 26          Untitled Victoria Beckham docuseries[439]
#
#                          Genre Language    Premiere  Seasons  Runtime  \
# 0                       Sports    Hindi        2024  Unknown  Unknown
# 1                       Nature  English        2024  Unknown  Unknown
# 2                   True crime   German    2024[80]  Unknown  Unknown
# 3                        Music   German    2024[80]  Unknown  Unknown
# 4                       Sports  English    2024[96]  Unknown  Unknown
# 5                       Sports  English  Early 2025  Unknown  Unknown
# 6   Emergency medical services  English        2025  Unknown  Unknown
# 7                       Sports  English        2025  Unknown  Unknown
# 8                       Nature  English        2025  Unknown  Unknown
# 9                   True crime  English        2026  Unknown  Unknown
# 10                      Sports  Spanish         TBA  Unknown  Unknown
# 11                     Culture  English         TBA  Unknown  Unknown
# 12                  True crime  English         TBA  Unknown  Unknown
# 13                  True crime   German         TBA  Unknown  Unknown
# 14                Social media  English         TBA  Unknown  Unknown
# 15                  True crime  English         TBA  Unknown  Unknown
# 16                      Sports  English         TBA  Unknown  Unknown
# 17                      Sports  English         TBA  Unknown  Unknown
# 18                   Celebrity  Spanish         TBA  Unknown  Unknown
# 19                      Sports  English         TBA  Unknown  Unknown
# 20                  True crime  English         TBA  Unknown  Unknown
# 21         Restaurant industry  English         TBA  Unknown  Unknown
# 22                  True crime  English         TBA  Unknown  Unknown
# 23                   Lifestyle  English         TBA  Unknown  Unknown
# 24                      Sports  English         TBA  Unknown  Unknown
# 25                       Music  English         TBA  Unknown  Unknown
# 26           Biography/Fashion  English         TBA  Unknown  Unknown
#
#       Status
# 0   Upcoming
# 1   Upcoming
# 2   Upcoming
# 3   Upcoming
# 4   Upcoming
# 5   Upcoming
# 6   Upcoming
# 7   Upcoming
# 8   Upcoming
# 9   Upcoming
# 10  Upcoming
# 11  Upcoming
# 12  Upcoming
# 13  Upcoming
# 14  Upcoming
# 15  Upcoming
# 16  Upcoming
# 17  Upcoming
# 18  Upcoming
# 19  Upcoming
# 20  Upcoming
# 21  Upcoming
# 22  Upcoming
# 23  Upcoming
# 24  Upcoming
# 25  Upcoming
# 26  Upcoming

# %%
upcomingReality_table_index = 49
upcomingReality_table = tables[upcomingReality_table_index]

# Extract table data
data = []
for row in upcomingReality_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingReality_df = pd.DataFrame(data, columns=['Title', 'Genre','Language', 'Premiere'])
upcomingReality_df['Seasons'] = 'Unknown'
upcomingReality_df['Runtime'] = 'Unknown'
upcomingReality_df['Status'] = 'Upcoming'
upcomingReality_df
# Out:
#                                      Title  \
# 0                      Comedy Revenge[182]
# 1   Rugged Rugby: Conquer or Die[440][182]
# 2            Love Is Blind: Argentina[441]
# 3              Love Is Blind: Germany[442]
# 4                  Kian's Bizarre B&B[182]
# 5     Sneaky Links: Dating After Dark[443]
# 6                           Bear Hunt[425]
# 7                         Battle Camp[175]
# 8                   Building the Band[444]
# 9       Cheaters: Unfinished Business[445]
# 10               Love Is Blind: Habibi[75]
# 11              Million Dollar Secret[446]
# 12                          Nova Cena[447]
# 13              Rhythm + Flow: Poland[448]
# 14                   Selling the City[449]
#
#                                      Genre    Language            Premiere  \
# 0                      Reality competition      Korean   October 2024[182]
# 1   Sports competition/Reality competition      Korean  December 2024[182]
# 2                              Dating show     Spanish           2024[135]
# 3                              Dating show      German             2024[6]
# 4                                  Reality      Korean     Early 2025[182]
# 5                              Dating show     English            Mid-2025
# 6                      Reality competition     English                2025
# 7                      Reality competition     English                 TBA
# 8                        Music competition     English                 TBA
# 9                                  Reality     English                 TBA
# 10                             Dating show      Arabic                 TBA
# 11                     Reality competition     English                 TBA
# 12                       Music competition  Portuguese                 TBA
# 13                       Music competition      Polish                 TBA
# 14                                 Reality     English                 TBA
#
#     Seasons  Runtime    Status
# 0   Unknown  Unknown  Upcoming
# 1   Unknown  Unknown  Upcoming
# 2   Unknown  Unknown  Upcoming
# 3   Unknown  Unknown  Upcoming
# 4   Unknown  Unknown  Upcoming
# 5   Unknown  Unknown  Upcoming
# 6   Unknown  Unknown  Upcoming
# 7   Unknown  Unknown  Upcoming
# 8   Unknown  Unknown  Upcoming
# 9   Unknown  Unknown  Upcoming
# 10  Unknown  Unknown  Upcoming
# 11  Unknown  Unknown  Upcoming
# 12  Unknown  Unknown  Upcoming
# 13  Unknown  Unknown  Upcoming
# 14  Unknown  Unknown  Upcoming

# %%
upcomingCoProd_table_index = 50
upcomingCoProd_table = tables[upcomingCoProd_table_index]

# Extract table data
data = []
for row in upcomingCoProd_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingCoProd_df = pd.DataFrame(data, columns=['Title','Partner/Country','Genre','Language', 'Premiere'])
upcomingCoProd_df=upcomingCoProd_df.drop('Partner/Country',axis=1)
upcomingCoProd_df['Seasons'] = 'Unknown'
upcomingCoProd_df['Runtime'] = 'Unknown'
upcomingCoProd_df['Status'] = 'Upcoming'
upcomingCoProd_df
# Out:
#                                       Title                    Genre  \
# 0                        Winter Palace[450]             Period drama
# 1                  Eddie's Lil' Homies[451]     Children's animation
# 2                            Lockerbie[452]         Drama miniseries
# 3                  North of North[453][454]                   Comedy
# 4  Untitled Front Populaire miniseries[455]  Period drama miniseries
#
#         Language   Premiere  Seasons  Runtime    Status
# 0  EnglishFrench  Late 2024  Unknown  Unknown  Upcoming
# 1        English        TBA  Unknown  Unknown  Upcoming
# 2        English        TBA  Unknown  Unknown  Upcoming
# 3        English        TBA  Unknown  Unknown  Upcoming
# 4         French        TBA  Unknown  Unknown  Upcoming

# %%
upcomingContinu_table_index = 51
upcomingContinu_table = tables[upcomingContinu_table_index]

# Extract table data
data = []
for row in upcomingContinu_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingContinu_df = pd.DataFrame(data, columns=['Title','Genre','Prev network(s)','Premiere','Seasons','Runtime','Language'])
upcomingContinu_df=upcomingContinu_df.drop('Prev network(s)',axis=1)
upcomingContinu_df['Status'] = 'Upcoming'
upcomingContinu_df
# Out:
#                                 Title                                Genre  \
# 0  My Lover My Killer (season 2)[456]                True crime docuseries
# 1   Weak Hero Class 1 (season 2)[457]  Coming-of-age action drama thriller
#
#   Premiere Seasons Runtime Language    Status
# 0      TBA     TBA     TBA  English  Upcoming
# 1      TBA     TBA     TBA   Korean  Upcoming

# %%
upcoming_table_index = 52
upcoming_table = tables[upcoming_table_index]

# Extract table data
data = []
for row in upcoming_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcoming_df = pd.DataFrame(data, columns=['Title','Genre','Language','Premiere'])
upcoming_df['Seasons'] = 'Unknown'
upcoming_df['Runtime'] = 'Unknown'
upcoming_df['Status'] = 'Upcoming'
upcoming_df
# Out:
#                   Title                   Genre Language Premiere  Seasons  \
# 0  Masameer Junior[414]  Adult animation comedy   Arabic      TBA  Unknown
#
#    Runtime    Status
# 0  Unknown  Upcoming

# %%
upcomingInDevelop_table_index = 53
upcomingInDevelop_table = tables[upcomingInDevelop_table_index]

# Extract table data
data = []
for row in upcomingInDevelop_table.find_all('tr')[1:]:  # Skip header row
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Create a DataFrame
upcomingInDevelop_df = pd.DataFrame(data, columns=['Title','Genre'])
upcomingInDevelop_df['Premiere'] = 'Unknown'
upcomingInDevelop_df['Seasons'] = 'Unknown'
upcomingInDevelop_df['Runtime'] = 'Unknown'
upcomingInDevelop_df['Language'] = 'English'
upcomingInDevelop_df['Status'] = 'In development'
upcomingInDevelop_df
# Out:
#                                                 Title  \
# 0                                         Anna O[458]
# 1                                     Arbor Hall[459]
# 2                                       Barbaric[460]
# 3                                        Bat Boy[461]
# 4                                     Birthright[462]
# 5                                      Calabasas[463]
# 6                                        Cashero[464]
# 7                                  Coming Undone[465]
# 8                           Death Note[466][467][468]
# 9                                         Dumped[469]
# 10                                  East of Eden[470]
# 11                            El cuco de cristal[471]
# 12                                    Fatherhood[472]
# 13                          Forever, Interrupted[473]
# 14                                     The Grays[474]
# 15                                   Happy Place[475]
# 16                                     The Hated[476]
# 17                              The Henna Artist[477]
# 18                         Last Samurai Standing[478]
# 19                                    Little Sky[479]
# 20                                     Mind MGMT[480]
# 21                                 Minor Threats[481]
# 22                                      Nocterra[482]
# 23                           One Day in December[483]
# 24                 Our Love Is Here to Stay[484][485]
# 25                       Princess of South Beach[486]
# 26                                  Revenge Inc.[487]
# 27        Something Is Killing the Children[488][489]
# 28                               Son of a Donkey[490]
# 29                                      Stronger[491]
# 30                        They'll Never Catch Us[492]
# 31  Untitled Charlie and the Chocolate Factory rea...
# 32      Untitled A Different World sequel series[494]
# 33                  Untitled "Daddy Ball" series[495]
# 34          Untitled Frank Sinatra biopic series[496]
# 35  Untitled Jeffrey Addiss and Will Matthews seri...
# 36           Untitled John F. Kennedy miniseries[497]
# 37                Untitled Julio Iglesias series[498]
# 38             Untitled Main Line murders series[499]
# 39                     Untitled Matt Rife series[500]
# 40    Untitled Maya and the Three-related series[501]
# 41                     Untitled Minecraft series[502]
# 42                 Untitled Myron Bolitar series[503]
# 43          Untitled One Tree Hill sequel series[504]
# 44               Untitled Owen Hanson docuseries[505]
# 45  Untitled Prince Harry and Meghan Markle script...
# 46            Untitled Regina Hicks project[506][507]
# 47                    Untitled Scooby-Doo series[508]
# 48                   Untitled Simon Riske series[509]
# 49          Untitled spiritual procedural series[510]
# 50  Untitled Stranger Things spin-off series[467][...
# 51                     Untitled U2 biopic series[512]
# 52                 Untitled Virgin River prequel[513]
# 53                                        Yasuke[514]
#
#                               Genre Premiere  Seasons  Runtime Language  \
# 0                    Crime thriller  Unknown  Unknown  Unknown  English
# 1             Teen mystery thriller  Unknown  Unknown  Unknown  English
# 2                  Medieval fantasy  Unknown  Unknown  Unknown  English
# 3         Young adult horror comedy  Unknown  Unknown  Unknown  English
# 4                             Drama  Unknown  Unknown  Unknown  English
# 5                        Teen drama  Unknown  Unknown  Unknown  English
# 21  In development
# 22  In development
# 23  In development
# 24  In development
# 25  In development
# 26  In development
# 27  In development
# 28  In development
# 29  In development
# 30  In development
# 31  In development
# 32  In development
# 33  In development
# 34  In development
# 35  In development
# 36  In development
# 37  In development
# 38  In development
# 39  In development
# 40  In development
# 41  In development
# 42  In development
# 43  In development
# 44  In development
# 45  In development
# 46  In development
# 47  In development
# 48  In development
# 49  In development
# 50  In development
# 51  In development
# 52  In development
# 53  In development

# %%
#List of DataFrames
dfs = [drama_df, comedy_df, kids_family_df,anime_df,fam_df ,arabic_df,french_df,german_df,hindi_df,indonesian_df,italian_df,
       japanese_df,korean_df,mandarin_df,polish_df,portuguese_df,spanish_df,swedish_df,thai_df,turkish_df,other_df,docuseries_df,
       reality_df,variety_df,continuation_df,episodic_df,regi_df,coprod_df,conti_df,upcomingDrama_df,upcomingComedy_df,
upcomingAnimation_df,upcomingAnime_df,upcomingKF_df,upcomingDutch_df,upcomingFrench_df,upcomingGerman_df,upcomingHindi_df
,upcomingItalian_df,upcomingJapanese_df,upcomingKorean_df,upcomingMandarin_df,upcomingNorwegian_df,upcomingPolish_df,
upcomingSpanish_df,upcomingSwedish_df,upcomingOtherLang_df,upcomingDoc_df,upcomingReality_df,upcomingCoProd_df,upcomingContinu_df,
upcoming_df,upcomingInDevelop_df] 

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)
final_df
# Out:
#                                                  Title  \
# 0                                      Stranger Things
# 1                                         Virgin River
# 2                                          The Witcher
# 3                                          Outer Banks
# 4                                      Sweet Magnolias
# ..                                                 ...
# 628          Untitled spiritual procedural series[510]
# 629  Untitled Stranger Things spin-off series[467][...
# 630                     Untitled U2 biopic series[512]
# 631                 Untitled Virgin River prequel[513]
# 632                                        Yasuke[514]
#
#                              Genre           Premiere                 Seasons  \
# 0           Science fiction horror      July 15, 2016  4 seasons, 34 episodes
# 1                   Romantic drama   December 6, 2019  5 seasons, 54 episodes
# 2                    Fantasy drama  December 20, 2019  3 seasons, 24 episodes
# 3              Coming-of-age drama     April 15, 2020  3 seasons, 30 episodes
# 4                   Romantic drama       May 19, 2020  3 seasons, 30 episodes
# ..                             ...                ...                     ...
# 628  Crime procedural/Supernatural            Unknown                 Unknown
# 629          Science fiction drama            Unknown                 Unknown
# 630                         Biopic            Unknown                 Unknown
# 631                 Romantic drama            Unknown                 Unknown
# 632                   Period drama            Unknown                 Unknown
#
#         Runtime                                             Status Language
# 0    42–150 min            Final season due to premiere in 2025[1]  English
# 1     39–52 min             Season 6 due to premiere in 2025[1][2]  English
# 2     47–67 min              Renewed for seasons 4–5 (final)[3][4]  English
# 3     42–79 min  Season 4 part 1 due to premiere on October 10,...  English
# 4     43–54 min             Season 4 due to premiere in 2025[1][8]  English
# ..          ...                                                ...      ...
# 628     Unknown                                     In development  English
# 629     Unknown                                     In development  English
# 630     Unknown                                     In development  English
# 631     Unknown                                     In development  English
# 632     Unknown                                     In development  English
#
# [633 rows x 7 columns]

# %%
# Save DataFrame to CSV
final_df.to_csv('netflix programming.csv', index=False)
